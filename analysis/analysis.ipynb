# %%
import os
from ros2profile.api.process import load_ctf, load_event_graph
from ros2profile.data.event_sequence import EventSequence

profile_dir = os.path.expanduser('~/.ros/profile/test-20230601221029/')
ctf_object = load_ctf(profile_dir)
ctf_object
#event_graph = load_event_graph(profile_dir)
# Out:
# defaultdict(list,
#             {'ros2:rcl_init': [{'_name': 'ros2:rcl_init',
#                '_timestamp': 1685657430456398538,
#                'context_handle': 94628407129920,
#                'version': '6.4.0',
#                'vtid': 3042852,
#                'vpid': 3042852,
#                'cpu_id': 12},
#               {'_name': 'ros2:rcl_init',
#                '_timestamp': 1685657430491941265,
#                'context_handle': 94091071879072,
#                'version': '6.4.0',
#                'vtid': 3042851,
#                'vpid': 3042851,
#                'cpu_id': 18}],
#              'ros2:rmw_publisher_init': [{'_name': 'ros2:rmw_publisher_init',
#                '_timestamp': 1685657430469051866,
#                'rmw_publisher_handle': 94628409043280,
#                'gid': [1,
#                 15,
#                 80,
#                 19,
#                 36,
#                 110,
#                 94,
#                 212,
#                 0,
# ...

# %%
import ros2profile.api
dir(ros2profile.api)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'get_output_directory',
#  'os',
#  'process',
#  'time']

# %%
import ros2profile.api.process
dir(ros2profile.api.process)
# Out:
# ['PROCESSORS',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'build_graph',
#  'glob',
#  'load_ctf',
#  'load_event_graph',
#  'load_mcap_data',
#  'mcap_ros2',
#  'os',
#  'pd',
#  'pickle',
#  'process',
#  'process_cpu_memory_usage',
#  'process_io_stats',
#  'process_memory_state',
#  'process_one',
#  'process_stat']

# %%
import ros2profile.data
dir(ros2profile.data)
# Out:
# ['Any',
#  'Callback',
#  'CallbackEvent',
#  'Context',
#  'Dict',
#  'Graph',
#  'IPPublishEvent',
#  'IpSubscriptionEvent',
#  'List',
#  'MessageInBuffer',
#  'Node',
#  'Optional',
#  'PublishEvent',
#  'Publisher',
#  'RawEvent',
#  'RawEventCollection',
#  'RawEvents',
#  'Subscription',
#  'SubscriptionEvent',
#  'Timer',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_associate_publish_events_to_subscription_callbacks',
#  '_associate_publish_events_to_timer_callbacks',
#  '_associate_publisher_to_callback',
#  '_associate_subscription_callbacks',
#  '_associate_subscription_event_to_publish_event',
#  '_associate_timer_callbacks',
#  '_build_callback_events',
#  '_build_callbacks',
#  '_build_contexts',
#  '_build_ip_publish_events',
#  '_build_ip_subscription_events',
#  '_build_nodes',
#  '_build_publish_events',
#  '_build_publishers',
#  '_build_subscription_events',
# ...
